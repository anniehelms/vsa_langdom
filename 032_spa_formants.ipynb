# %% [markdown]
# # Get Spanish Formant trajectories

# %%
import parselmouth
from parselmouth.praat import call
import os
import re
import csv
import pandas as pd
from audiolabel import read_label

# %% [markdown]
# ### First get data for female speakers with max Hz set to 5500 Hz

# %%
# directory of MFA'ed TextGrids
tg_path = 'data/spanish/female/'
# directory of wav files
wav_path = 'data/spanish/female/'
# directory to save vowel measurement data
data_path = 'data/'


# formant analysis parameters
time_step = 0.1
maximum_number_of_formants = 5
maximum_formant = 5500 # Hz for adult female
window_length = 0.025 # seconds
preemphasis_from = 50

# take formant measurements every X seconds?
segment_window = 0.005 # 5 milliseconds

# %%
# list (of dictionaries) to save results to
data = []

# counter to keep track of how long this script takes to run
file_counter = 1

for file in os.listdir(wav_path):
    if file.endswith('.wav'):
        
        # Check if corresponding TextGrid exists
        if os.path.exists(tg_path + file[:-4] + '.TextGrid'):
            
            # Print out which file we're currently working on
            print(file_counter, 'Processing file', file)
            file_counter += 1
            
            if file.startswith("s"):
                # names of tiers with phonemes of interest
                phones_tiers = ['phone']
            
            else:
                # names of tiers with phonemes of interest
                phones_tiers = ['default - phones']
            
            # Create sound object
            wav = parselmouth.Sound(wav_path + file)
            
            # Create formant object
            formant = wav.to_formant_burg(time_step, maximum_number_of_formants, maximum_formant, window_length, preemphasis_from)
            
            # Open textgrid
            tg = parselmouth.Data.read(tg_path + file[:-4] + '.TextGrid')
            
            # Iterate over the tiers and find the ones w/ phonemes
            numTiers = call(tg, 'Get number of tiers')
            for tierIdx in range(1, numTiers + 1): # Praat counts from 1, not 0
                tierName = call(tg, 'Get tier name', tierIdx)
                
                if tierName in phones_tiers:
                    numIntervals = call(tg, 'Get number of intervals', tierIdx)
                    
                    for intervalIdx in range(1, numIntervals + 1):
                        label = call(tg, 'Get label of interval', tierIdx, intervalIdx)
                        
                        # check if interval label is a vowel,
                        # i.e., it is not blank, and it ends in a digit
                        vowel_list = ["a", "a+", "e", "e+", "i", "i+", "o", "o+", "u", "u+", "aI", "aU", "oI", "j", "w"]
                        if label and label in vowel_list:
                            start = call(tg, 'Get starting point', tierIdx, intervalIdx)
                            end = call(tg, 'Get end point', tierIdx, intervalIdx)
                            dur = end - start
                            
                            # number of X millisecond segments to take measurements from
                            numSegments = int(dur / segment_window) # note: this must be an integer
                            
                            # loop over segments and calculate F1/F2
                            for segmentIdx in range(1, numSegments + 1):
                                spot = start + (segmentIdx * segment_window)
                                tim_int = spot - start
                                
                                f1 = call(formant, 'Get value at time', 1, spot, 'Hertz', 'Linear')
                                f2 = call(formant, 'Get value at time', 2, spot, 'Hertz', 'Linear')
                                f3 = call(formant, 'Get value at time', 3, spot, 'Hertz', 'Linear')
                                
                                # add to our data set
                                data.append({'Video ID': file[:-4],
                                             'Vowel': label,
                                             't1_ph': start,
                                             'Time_of_formant_measurements': spot,
                                             'Time_from_vowel_onset': tim_int,
                                             'F1': f1,
                                             'F2': f2,
                                             'F3': f3,
                                             'Tier': tierName,
                                            })
        
print('Done')
# Out:
# 1 Processing file p111_spanish1.wav
# 2 Processing file p111_spanish2.wav
# 3 Processing file p111_spanish3.wav
# 4 Processing file p113_spanish1.wav
# 5 Processing file p113_spanish2.wav
# 212 Processing file s05629.wav
# 213 Processing file s05630.wav
# 214 Processing file s05631.wav
# 215 Processing file s05632.wav
# 216 Processing file s05633.wav
# 217 Processing file s05634.wav
# 218 Processing file s05635.wav
# 219 Processing file s05636.wav
# 220 Processing file s05637.wav
# 221 Processing file s05638.wav
# 222 Processing file s05639.wav
# 223 Processing file s05640.wav
# 224 Processing file s05641.wav
# 225 Processing file s05642.wav
# 226 Processing file s05643.wav
# 227 Processing file s05644.wav
# 228 Processing file s05645.wav
# 229 Processing file s05646.wav
# 230 Processing file s05647.wav
# 231 Processing file s05648.wav
# 232 Processing file s05649.wav
# 233 Processing file s05650.wav
# Done

# %% [markdown]
# Make sure to rename data for males so they can be run separately

# %%
data[0]
# Out:
# {'Video ID': 'p111_spanish1',
#  'Vowel': 'a',
#  't1_ph': 8.178,
#  'Time_of_formant_measurements': 8.183000000000002,
#  'Time_from_vowel_onset': 0.005000000000000782,
#  'F1': 579.9256822556335,
#  'F2': 1318.6660546903286,
#  'F3': 2603.4668149064714,
#  'Tier': 'default - phones'}

# %% [markdown]
# ### Now the male data, where max Hz set to 5000

# %%
# directory of MFA'ed TextGrids
tg_path = 'data/spanish/male/'
# directory of wav files
wav_path = 'data/spanish/male/'
# directory to save vowel measurement data
data_path = 'data/'


# formant analysis parameters
time_step = 0.1
maximum_number_of_formants = 5
maximum_formant = 5000 # Hz for adult male
window_length = 0.025 # seconds
preemphasis_from = 50

# take formant measurements every X seconds?
segment_window = 0.005 # 5 milliseconds

# %%
# list (of dictionaries) to save results to
data_male = []

# counter to keep track of how long this script takes to run
file_counter = 1

for file in os.listdir(wav_path):
    if file.endswith('.wav'):
        
        # Check if corresponding TextGrid exists
        if os.path.exists(tg_path + file[:-4] + '.TextGrid'):
            
            # Print out which file we're currently working on
            print(file_counter, 'Processing file', file)
            file_counter += 1
            
            if file.startswith("s"):
                # names of tiers with phonemes of interest
                phones_tiers = ['phone']
            
            else:
                # names of tiers with phonemes of interest
                phones_tiers = ['default - phones']
            
            # Create sound object
            wav = parselmouth.Sound(wav_path + file)
            
            # Create formant object
            formant = wav.to_formant_burg(time_step, maximum_number_of_formants, maximum_formant, window_length, preemphasis_from)
            
            # Open textgrid
            tg = parselmouth.Data.read(tg_path + file[:-4] + '.TextGrid')
            
            # Iterate over the tiers and find the ones w/ phonemes
            numTiers = call(tg, 'Get number of tiers')
            for tierIdx in range(1, numTiers + 1): # Praat counts from 1, not 0
                tierName = call(tg, 'Get tier name', tierIdx)
                
                if tierName in phones_tiers:
                    numIntervals = call(tg, 'Get number of intervals', tierIdx)
                    
                    for intervalIdx in range(1, numIntervals + 1):
                        label = call(tg, 'Get label of interval', tierIdx, intervalIdx)
                        
                        # check if interval label is a vowel,
                        # i.e., it is not blank, and it ends in a digit
                        vowel_list = ["a", "a+", "e", "e+", "i", "i+", "o", "o+", "u", "u+", "aI", "aU", "oI", "j", "w"]
                        if label and label in vowel_list:
                            start = call(tg, 'Get starting point', tierIdx, intervalIdx)
                            end = call(tg, 'Get end point', tierIdx, intervalIdx)
                            dur = end - start
                            
                            # number of X millisecond segments to take measurements from
                            numSegments = int(dur / segment_window) # note: this must be an integer
                            
                            # loop over segments and calculate F1/F2
                            for segmentIdx in range(1, numSegments + 1):
                                spot = start + (segmentIdx * segment_window)
                                tim_int = spot - start
                                
                                f1 = call(formant, 'Get value at time', 1, spot, 'Hertz', 'Linear')
                                f2 = call(formant, 'Get value at time', 2, spot, 'Hertz', 'Linear')
                                f3 = call(formant, 'Get value at time', 3, spot, 'Hertz', 'Linear')
                                
                                # add to our data set
                                data_male.append({'Video ID': file[:-4],
                                             'Vowel': label,
                                             't1_ph': start,
                                             'Time_of_formant_measurements': spot,
                                             'Time_from_vowel_onset': tim_int,
                                             'F1': f1,
                                             'F2': f2,
                                             'F3': f3,
                                             'Tier': tierName,
                                            })
        
print('Done')
# Out:
# 1 Processing file p119_spanish1.wav
# 2 Processing file p119_spanish2.wav
# 3 Processing file p119_spanish3.wav
# 4 Processing file s00101.wav
# 5 Processing file s00102.wav
# 6 Processing file s00103.wav
# 7 Processing file s00104.wav
# 8 Processing file s00105.wav
# 9 Processing file s00106.wav
# 10 Processing file s00107.wav
# 11 Processing file s00108.wav
# 12 Processing file s00109.wav
# 13 Processing file s00110.wav
# 14 Processing file s00111.wav
# 15 Processing file s00112.wav
# 16 Processing file s00113.wav
# 17 Processing file s00114.wav
# 18 Processing file s00115.wav
# 19 Processing file s00116.wav
# 20 Processing file s00117.wav
# 21 Processing file s00118.wav
# 22 Processing file s00119.wav
# 23 Processing file s00120.wav
# 24 Processing file s00121.wav
# 25 Processing file s00122.wav
# 26 Processing file s00123.wav
# 27 Processing file s00124.wav
# 28 Processing file s00125.wav
# 29 Processing file s00126.wav
# 30 Processing file s00127.wav
# 31 Processing file s00128.wav
# 32 Processing file s00129.wav
# 33 Processing file s00130.wav
# 34 Processing file s00131.wav
# 35 Processing file s00132.wav
# 36 Processing file s00133.wav
# 37 Processing file s00134.wav
# 38 Processing file s00135.wav
# 39 Processing file s00136.wav
# 40 Processing file s00137.wav
# 41 Processing file s00138.wav
# 42 Processing file s00139.wav
# 43 Processing file s00140.wav
# 44 Processing file s00141.wav
# 45 Processing file s00142.wav
# 46 Processing file s00143.wav
# 47 Processing file s00144.wav
# 48 Processing file s00145.wav
# 49 Processing file s00146.wav
# 50 Processing file s00147.wav
# 51 Processing file s00148.wav
# 52 Processing file s00149.wav
# 53 Processing file s00150.wav
# 54 Processing file s00201.wav
# 55 Processing file s00202.wav
# 56 Processing file s00203.wav
# 57 Processing file s00204.wav
# 58 Processing file s00205.wav
# 59 Processing file s00206.wav
# 60 Processing file s00207.wav
# 61 Processing file s00208.wav
# 62 Processing file s00209.wav
# 63 Processing file s00210.wav
# 64 Processing file s00211.wav
# 65 Processing file s00212.wav
# 66 Processing file s00213.wav
# 67 Processing file s00214.wav
# 68 Processing file s00215.wav
# 69 Processing file s00216.wav
# 70 Processing file s00217.wav
# 71 Processing file s00218.wav
# 72 Processing file s00219.wav
# 73 Processing file s00220.wav
# 74 Processing file s00221.wav
# 75 Processing file s00222.wav
# 76 Processing file s00223.wav
# 77 Processing file s00224.wav
# 78 Processing file s00225.wav
# 79 Processing file s00226.wav
# 80 Processing file s00227.wav
# 81 Processing file s00228.wav
# 82 Processing file s00229.wav
# 83 Processing file s00230.wav
# 84 Processing file s00231.wav
# 85 Processing file s00232.wav
# 86 Processing file s00233.wav
# 87 Processing file s00234.wav
# 88 Processing file s00235.wav
# 89 Processing file s00236.wav
# 90 Processing file s00237.wav
# 91 Processing file s00238.wav
# 92 Processing file s00239.wav
# 93 Processing file s00240.wav
# 94 Processing file s00241.wav
# 95 Processing file s00242.wav
# 96 Processing file s00243.wav
# 97 Processing file s00244.wav
# 98 Processing file s00245.wav
# 99 Processing file s00246.wav
# 100 Processing file s00247.wav
# 101 Processing file s00248.wav
# 102 Processing file s00249.wav
# 103 Processing file s00250.wav
# Done

# %%
data_male[0]
# Out:
# {'Video ID': 'p119_spanish1',
#  'Vowel': 'a',
#  't1_ph': 64.827,
#  'Time_of_formant_measurements': 64.832,
#  'Time_from_vowel_onset': 0.0049999999999954525,
#  'F1': 638.6783281436159,
#  'F2': 1223.5057006037123,
#  'F3': 2640.21525844693,
#  'Tier': 'default - phones'}

# %% [markdown]
# ### Combine formant data and create DataFrame

# %%
formant_list = data + data_male
formantdf = pd.DataFrame(formant_list)
formantdf.sample(25)
# Out:
#              Video ID Vowel    t1_ph  Time_of_formant_measurements  \
# 98961   p118_spanish1     a   76.198                        76.243
# 351577         s00128     i    1.463                         1.503
# 165402  p121_spanish3     a  275.024                       275.089
# 254936  p126_spanish3     j  185.428                       185.453
# 353844         s00138     o    0.522                         0.532
# 346199         s00104     a    1.424                         1.499
# 151828  p121_spanish2     e  151.401                       151.516
# 325357  p119_spanish1     o  128.789                       129.009
# 77251   p117_spanish1     a  115.374                       115.449
# 137410  p120_spanish3     o  273.987                       274.127
# 68038   p114_spanish3     i   71.297                        71.317
# 198500  p123_spanish2     e  123.019                       123.054
# 98971   p118_spanish1     a   76.198                        76.293
# 33458   p113_spanish1     e  443.920                       443.940
# 369010         s00244     a    0.598                         0.663
# 127266  p120_spanish2     i  143.264                       143.319
# 74691   p114_spanish3     a  307.226                       307.236
# 175272  p122_spanish2     a  105.009                       105.049
# 229185  p124_spanish3     o  281.298                       281.383
# 223959  p124_spanish3     o    4.789                         4.819
# 265334         s05124     e    0.703                         0.748
# 1212    p111_spanish1     a   53.303                        53.328
# 6961    p111_spanish1     a  295.588                       295.628
# 135624  p120_spanish3    o+  188.921                       188.926
# 227796  p124_spanish3     o  216.190                       216.195
#
#         Time_from_vowel_onset           F1           F2           F3  \
# 98961                   0.045   659.990375  1506.636368  2657.549528
# 351577                  0.040   293.938955  2055.809116  2901.571643
# 165402                  0.065   853.630167  1714.294645  2789.465939
# 254936                  0.025   679.285254  2310.842689  2962.021673
# 353844                  0.010   426.420652  1432.112157  2642.818171
# 346199                  0.075  1055.060125  2335.000175  2953.909775
# 151828                  0.115   517.968364  1735.031739  2369.876739
# 325357                  0.220  1019.400107  1878.236408  2931.310383
# 77251                   0.075   601.960162   943.709018  2359.306308
# 137410                  0.140   786.945541  1786.270180  2238.905263
# 68038                   0.020   339.570096  2599.518627  3151.898373
# 198500                  0.035   719.308882  2205.722615  2470.836841
# 98971                   0.095   659.895772  1563.369074  2741.882208
# 33458                   0.020   545.017144  1733.209620  2722.734463
# 369010                  0.065   781.972300  1708.580538  2698.827255
# 127266                  0.055   423.252344  2211.122558  2884.346090
# 74691                   0.010   724.419778  1691.343238  2774.642240
# 175272                  0.040   786.173041  1472.690901  2846.881957
# 229185                  0.085   789.235311  1487.412089  3195.033671
# 223959                  0.030   639.684400  1273.052191  3232.226906
# 265334                  0.045   624.237154  1949.597524  3063.786508
# 1212                    0.025   838.815372  1698.782177  2600.576007
# 6961                    0.040   670.223427  1525.558831  1721.342765
# 135624                  0.005   606.550195  1925.228503  2943.787770
# 227796                  0.005   404.245697  1619.159711  2966.490566
#
#                     Tier
# 98961   default - phones
# 351577             phone
# 165402  default - phones
# 254936  default - phones
# 353844             phone
# 346199             phone
# 151828  default - phones
# 325357  default - phones
# 77251   default - phones
# 137410  default - phones
# 68038   default - phones
# 198500  default - phones
# 98971   default - phones
# 33458   default - phones
# 369010             phone
# 127266  default - phones
# 74691   default - phones
# 175272  default - phones
# 229185  default - phones
# 223959  default - phones
# 265334             phone
# 1212    default - phones
# 6961    default - phones
# 135624  default - phones
# 227796  default - phones

# %%
# save formants to csv
formantdf.to_csv("data/formants_spa.csv", index = False)

# %% [markdown]
# ### Merge with tg df

# %%
tgdf = pd.read_csv("data/tg_data.csv")
tgdf.head()
# Out:
#     t1_ph   t2_ph                            fname  dur_ph Participant Corpus  \
# 0   8.068   8.178  data/tgs/p111_spanish1.TextGrid    0.11        p111   CBAS
# 1   8.178   8.278  data/tgs/p111_spanish1.TextGrid    0.10        p111   CBAS
# 2   8.278   8.368  data/tgs/p111_spanish1.TextGrid    0.09        p111   CBAS
# 3   8.368   8.558  data/tgs/p111_spanish1.TextGrid    0.19        p111   CBAS
# 4  10.477  10.567  data/tgs/p111_spanish1.TextGrid    0.09        p111   CBAS
#
#     t1_wd   t2_wd   word  is_wdinit_ph  is_wdfin_ph  is_stress GP_ph  is_vowel
# 0   8.068   8.558   bajo          True        False          1     b         0
# 1   8.068   8.558   bajo         False        False          1     a         1
# 2   8.068   8.558   bajo         False        False          0     x         0
# 3   8.068   8.558   bajo         False         True          0     o         1
# 4  10.477  10.957  zombi          True        False          1     s         0

# %% [markdown]
# Create new column `Video ID` that has rows of form `p111_spanish1`

# %%
tgdf['Video ID'] = tgdf['fname'].apply(lambda x: x[9:-9])
tgdf.head()
# Out:
#     t1_ph   t2_ph                            fname  dur_ph Participant Corpus  \
# 0   8.068   8.178  data/tgs/p111_spanish1.TextGrid    0.11        p111   CBAS
# 1   8.178   8.278  data/tgs/p111_spanish1.TextGrid    0.10        p111   CBAS
# 2   8.278   8.368  data/tgs/p111_spanish1.TextGrid    0.09        p111   CBAS
# 3   8.368   8.558  data/tgs/p111_spanish1.TextGrid    0.19        p111   CBAS
# 4  10.477  10.567  data/tgs/p111_spanish1.TextGrid    0.09        p111   CBAS
#
#     t1_wd   t2_wd   word  is_wdinit_ph  is_wdfin_ph  is_stress GP_ph  \
# 0   8.068   8.558   bajo          True        False          1     b
# 1   8.068   8.558   bajo         False        False          1     a
# 2   8.068   8.558   bajo         False        False          0     x
# 3   8.068   8.558   bajo         False         True          0     o
# 4  10.477  10.957  zombi          True        False          1     s
#
#    is_vowel       Video ID
# 0         0  p111_spanish1
# 1         1  p111_spanish1
# 2         0  p111_spanish1
# 3         1  p111_spanish1
# 4         0  p111_spanish1

# %% [markdown]
# Now the two dataframes can be merged on `Video ID` and `t1_ph`

# %%
spa_tgformants = tgdf.merge(formantdf, on=['Video ID', 't1_ph'])
spa_tgformants.head(50)
# Out:
#     t1_ph  t2_ph                            fname  dur_ph Participant Corpus  \
# 0   8.178  8.278  data/tgs/p111_spanish1.TextGrid    0.10        p111   CBAS
#
# 44      o                        8.498                 0.130   920.138470
# 45      o                        8.503                 0.135   946.838074
# 46      o                        8.508                 0.140   973.537677
# 47      o                        8.513                 0.145  1000.237281
# 48      o                        8.518                 0.150  1026.936885
# 49      o                        8.523                 0.155  1053.636488
#
#              F2           F3              Tier
# 0   1318.666055  2603.466815  default - phones
# 1   1308.964840  2600.082277  default - phones
# 2   1299.263625  2596.697739  default - phones
# 3   1289.562411  2593.313201  default - phones
# 4   1279.861196  2589.928663  default - phones
# 5   1270.159981  2586.544125  default - phones
# 6   1260.458767  2583.159587  default - phones
# 7   1250.757552  2579.775049  default - phones
# 8   1241.056337  2576.390511  default - phones
# 9   1231.355123  2573.005973  default - phones
# 10  1225.132234  2579.897774  default - phones
# 11  1218.912503  2586.798903  default - phones
# 12  1212.692772  2593.700033  default - phones
# 13  1206.473042  2600.601162  default - phones
# 14  1200.253311  2607.502292  default - phones
# 15  1194.033580  2614.403421  default - phones
# 16  1187.813849  2621.304551  default - phones
# 17  1181.594118  2628.205681  default - phones
# 18  1175.374388  2635.106810  default - phones
# 19  1022.121142  2652.368114  default - phones
# 20  1012.694574  2645.849970  default - phones
# 21  1003.268006  2639.331827  default - phones
# 22   993.841437  2632.813683  default - phones
# 23   984.414869  2626.295539  default - phones
# 24   974.988301  2619.777396  default - phones
# 25   965.561732  2613.259252  default - phones
# 26   956.135164  2606.741108  default - phones
# 27   946.708596  2600.222965  default - phones
# 28   937.282027  2593.704821  default - phones
# 29   927.855459  2587.186677  default - phones
# 30   918.428890  2580.668534  default - phones
# 31   970.349578  2608.711802  default - phones
# 32  1022.325960  2636.786447  default - phones
# 33  1074.302342  2664.861093  default - phones
# 34  1126.278725  2692.935738  default - phones
# 35  1178.255107  2721.010383  default - phones
# 36  1230.231489  2749.085028  default - phones
# 37  1282.207871  2777.159674  default - phones
# 38  1334.184253  2805.234319  default - phones
# 39  1386.160635  2833.308964  default - phones
# 40  1438.137017  2861.383609  default - phones
# 41  1490.113399  2889.458255  default - phones
# 42  1542.089781  2917.532900  default - phones
# 43  1594.066163  2945.607545  default - phones
# 44  1646.042545  2973.682190  default - phones
# 45  1698.018927  3001.756836  default - phones
# 46  1749.995310  3029.831481  default - phones
# 47  1801.971692  3057.906126  default - phones
# 48  1853.948074  3085.980771  default - phones
# 49  1905.924456  3114.055417  default - phones
#
# [50 rows x 22 columns]

# %%
spa_tgformants.shape
# Out:
# (355115, 22)

# %% [markdown]
# Add in language dominance information.

# %%
langdom = pd.DataFrame({"Participant": ['p111', 'p113', 'p114', 'p117','p118', 'p119', 'p120', 'p121', 'p122', 'p123', 'p124', 'p126', 's051', 's053', 's055', 's056', 's001', 's002'],
                       "Dom": ["L2", "biling", "biling", "L2", "biling", "biling", "biling", "L2", "biling", "L2", "biling", "L2", "mono", "mono", "mono", "mono", "mono", "mono"]})

# %%
spa_tgformants = spa_tgformants.merge(langdom, on = ["Participant"])
spa_tgformants.sample(10)
# Out:
#           t1_ph    t2_ph                            fname  dur_ph Participant  \
# 254678  159.417  159.607  data/tgs/p126_spanish1.TextGrid   0.190        p126
# 258575   37.840   38.140  data/tgs/p126_spanish2.TextGrid   0.300        p126
# 140663  146.172  146.272  data/tgs/p120_spanish1.TextGrid   0.100        p120
# 79545   291.280  291.350  data/tgs/p117_spanish1.TextGrid   0.070        p117
# 176518  292.738  292.978  data/tgs/p121_spanish2.TextGrid   0.240        p121
# 89227    43.200   43.410  data/tgs/p117_spanish3.TextGrid   0.210        p117
# 117830  144.852  144.902  data/tgs/p119_spanish1.TextGrid   0.050        p119
# 201378   85.322   85.492  data/tgs/p122_spanish3.TextGrid   0.170        p122
# 292736    1.326    1.375         data/tgs/s00233.TextGrid   0.049        s002
# 15237   189.200  189.360  data/tgs/p111_spanish2.TextGrid   0.160        p111
#
#           Corpus    t1_wd    t2_wd      word  is_wdinit_ph  ...  is_vowel  \
# 254678      CBAS  159.037  159.607    convoy         False  ...         1
# 258575      CBAS   37.840   38.140       hoy          True  ...         1
# 140663      CBAS  145.902  146.612    baliza         False  ...         1
# 79545       CBAS  291.280  291.970   amargas          True  ...         1
# 176518      CBAS  292.398  292.978     llave         False  ...         1
# 89227       CBAS   42.860   43.410     harto         False  ...         1
# 117830      CBAS  144.742  145.302   águilas         False  ...         1
# 201378      CBAS   84.862   85.492  convicto         False  ...         1
# 292736  DIMEx100    1.255    1.375        no         False  ...         1
# 15237       CBAS  188.720  189.360  alfombra         False  ...         1
#
#              Video ID Vowel  Time_of_formant_measurements  \
# 254678  p126_spanish1    oI                       159.472
# 258575  p126_spanish2    oI                        38.025
# 140663  p120_spanish1     i                       146.242
# 79545   p117_spanish1     a                       291.290
# 176518  p121_spanish2     e                       292.903
# 89227   p117_spanish3     o                        43.345
# 117830  p119_spanish1     i                       144.867
# 201378  p122_spanish3     o                        85.482
# 292736         s00233     o                         1.361
# 15237   p111_spanish2     a                       189.240
#
#        Time_from_vowel_onset          F1           F2           F3  \
# 254678                 0.055  656.511153  1224.573849  2948.632876
# 258575                 0.185  585.120140  1601.267958  2748.333918
# 140663                 0.070  302.370388  2245.727048  3090.625502
# 79545                  0.010  601.696188  1366.345256  2954.026484
# 176518                 0.165  764.375014  2326.820500  2972.874795
# 89227                  0.145  804.705760  1846.427142  3384.405734
# 117830                 0.015  451.552872  2060.199878  2458.221435
# 201378                 0.160  778.399504  1679.287926  2757.961692
# 292736                 0.035  640.010069  1490.404080  2788.383900
# 15237                  0.040  699.419593  1619.674360  2678.488907
#
#                     Tier     Dom
# 254678  default - phones      L2
# 258575  default - phones      L2
# 140663  default - phones  biling
# 79545   default - phones      L2
# 176518  default - phones      L2
# 89227   default - phones      L2
# 117830  default - phones  biling
# 201378  default - phones  biling
# 292736             phone    mono
# 15237   default - phones      L2
#
# [10 rows x 23 columns]

# %% [markdown]
# Create column for average vowel duration, by Participant.

# %%
avg_dur = pd.DataFrame(spa_tgformants.groupby(["Participant"])["dur_ph"].mean())
avg_dur = avg_dur.rename(columns={"dur_ph": "avg_dur"})
avg_dur = avg_dur.reset_index(drop = False)
avg_dur.head()
# Out:
#   Participant   avg_dur
# 0        p111  0.120470
# 1        p113  0.136585
# 2        p114  0.158571
# 3        p117  0.110605
# 4        p118  0.113432

# %%
spa_tgformants = spa_tgformants.merge(avg_dur, on = ["Participant"])
spa_tgformants.sample(10)
# Out:
#           t1_ph    t2_ph                            fname  dur_ph Participant  \
# 11470   460.377  460.417  data/tgs/p111_spanish1.TextGrid    0.04        p111
# 45525    64.528   64.608  data/tgs/p113_spanish3.TextGrid    0.08        p113
# 154925  156.273  156.423  data/tgs/p120_spanish3.TextGrid    0.15        p120
# 178923   74.600   74.700  data/tgs/p121_spanish3.TextGrid    0.10        p121
# 206334   33.016   33.086  data/tgs/p123_spanish1.TextGrid    0.07        p123
# 128441  242.877  242.927  data/tgs/p119_spanish2.TextGrid    0.05        p119
# 102074  257.162  257.292  data/tgs/p118_spanish1.TextGrid    0.13        p118
# 214343   36.210   36.280  data/tgs/p123_spanish2.TextGrid    0.07        p123
# 70070   171.659  171.859  data/tgs/p114_spanish3.TextGrid    0.20        p114
# 263400  192.196  192.266  data/tgs/p126_spanish2.TextGrid    0.07        p126
#
#        Corpus    t1_wd    t2_wd         word  is_wdinit_ph  ...  \
# 11470    CBAS  460.167  460.897   presidente         False  ...
# 45525    CBAS   64.378   64.608          muy         False  ...
# 154925   CBAS  156.193  156.873        limbo         False  ...
# 178923   CBAS   73.890   74.890   alumbrador         False  ...
# 206334   CBAS   32.946   33.586      carbono         False  ...
# 128441   CBAS  242.667  243.367      revocar         False  ...
# 102074   CBAS  256.812  257.492     vainilla         False  ...
# 214343   CBAS   35.610   36.610  ubicaciones         False  ...
# 70070    CBAS  171.419  171.859         pedí         False  ...
# 263400   CBAS  191.726  192.616       labios         False  ...
#
#              Video ID  Vowel Time_of_formant_measurements  \
# 11470   p111_spanish1      i                      460.387
# 45525   p113_spanish3      j                       64.583
# 154925  p120_spanish3      i                      156.373
# 178923  p121_spanish3      o                       74.655
# 206334  p123_spanish1      a                       33.036
# 128441  p119_spanish2      e                      242.892
# 102074  p118_spanish1      i                      257.207
# 214343  p123_spanish2      o                       36.255
# 70070   p114_spanish3     i+                      171.859
# 263400  p126_spanish2      o                      192.231
#
#         Time_from_vowel_onset          F1           F2           F3  \
# 11470                   0.010  391.273433  1689.053077  2819.876091
# 45525                   0.055  475.978958  2018.910884  2896.605957
# 154925                  0.100  319.632891   632.412420  2693.291462
# 178923                  0.055  615.236577  1140.460094  2825.200258
# 206334                  0.020  677.317915  1696.055083  2488.443460
# 128441                  0.015  363.574930  1827.486108  2252.279105
# 102074                  0.045  377.417689  1651.281411  3155.685305
# 214343                  0.045  737.614428  1510.343168  2620.050315
# 70070                   0.200  458.005003  2357.068575  3236.598929
# 263400                  0.035  537.481546  1859.949349  2884.633526
#
#                     Tier     Dom   avg_dur
# 11470   default - phones      L2  0.120470
# 45525   default - phones  biling  0.136585
# 154925  default - phones  biling  0.140621
# 178923  default - phones      L2  0.153949
# 206334  default - phones      L2  0.131626
# 128441  default - phones  biling  0.141896
# 102074  default - phones  biling  0.113432
# 214343  default - phones      L2  0.131626
# 70070   default - phones  biling  0.158571
# 263400  default - phones      L2  0.165465
#
# [10 rows x 24 columns]

# %%
spa_tgformants.to_csv("data/spanish_vowels.csv", index = False)

# %%
import pandas as pd
df = pd.read_csv("data/spanish_vowels.csv")
df.groupby(['Participant','t1_ph'])["Vowel"].count().shape
# Out:
# (18645,)
